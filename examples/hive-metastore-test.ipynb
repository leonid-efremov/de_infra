# %%
# !pip install hive-metastore-client
# Out:
# Collecting hive-metastore-client
#   Downloading hive_metastore_client-1.0.9-py3-none-any.whl.metadata (5.1 kB)
# Collecting thrift==0.13.0 (from hive-metastore-client)
#   Downloading thrift-0.13.0.tar.gz (59 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: six>=1.7.2 in /opt/conda/lib/python3.11/site-packages (from thrift==0.13.0->hive-metastore-client) (1.16.0)
# Downloading hive_metastore_client-1.0.9-py3-none-any.whl (137 kB)
# Building wheels for collected packages: thrift
#   Building wheel for thrift (pyproject.toml) ... done
#   Created wheel for thrift: filename=thrift-0.13.0-py3-none-any.whl size=199496 sha256=3fcdf8655528c177dce68718fceee2822993c9c9d0c60604b84407ad9b884ddd
#   Stored in directory: /home/jovyan/.cache/pip/wheels/d3/95/9b/941413047c37cbfb96c016dd4ec91e275e0283c231f42b2315
# Successfully built thrift
# Installing collected packages: thrift, hive-metastore-client
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [hive-metastore-client]-metastore-client]
# Successfully installed hive-metastore-client-1.0.9 thrift-0.13.0

# %%
from hive_metastore_client.builders import DatabaseBuilder
from hive_metastore_client import HiveMetastoreClient

HIVE_HOST = "hive-metastore"
HIVE_PORT = 9083

# %%
database = DatabaseBuilder("test_db").build()

# %%
with HiveMetastoreClient(HIVE_HOST, HIVE_PORT) as hive_client:
    hive_client.create_database(database)
